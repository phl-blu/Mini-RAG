# %%
# import numpy
# import math
# import matplotlib
# import pandas
import numpy as np
import math
import matplotlib as plt
import pandas as pd
from collections import Counter

# %%
# Declare the 2 vectors
A = [2,3]
B = [5,1]

# %%
print(A)
# Out:
# [2, 3]

# %%
print(B)
# Out:
# [5, 1]

# %%
# calculate dot product

# if A contains mor elements than B, then length = A; else length = B
if A > B:
  length = len(A) #length A
else:
  length = len(B) #length B

# Renamed 'sum' to 'dot_product_sum' to avoid shadowing built-in sum()
dot_product_sum = 0
for i in range(length):
  dot_product_sum = dot_product_sum + A[i] * B[i]

# %%
# print summ
print(dot_product_sum)
# Out:
# 13

# %%
# calculate cosine similarity
# cos similarity = dot product /  ||A|| * ||B||

lengthA = math.sqrt(A[0]**2 + A[1]**2) # ** is exponent
lengthB = math.sqrt(B[0]**2 + B[1]**2)


cosAB = dot_product_sum / (lengthA*lengthB)

print(cosAB)
# Out:
# 0.7071067811865476

# %%
# calculate euclidean distance
euclidean = math.sqrt((B[0] - A[0])**2 + (B[1] - A[1])**2)
print(euclidean)
# Out:
# 3.605551275463989

# %% [markdown]
# Testing TF Concept

# %%
doc1 = "test test test apple watermelon mango"
doc2 = "it's very hot today"
doc3 = "i drank apple and watermelon juice today because it was hot"

# cut into substrings first aka tokenization
token1 = doc1.split(" ")
token2 = doc2.split(" ")
token3 = doc3.split(" ")

# %%
# posting list token1
# This gives "test": ["doc1", "doc1", "doc1"] when test appears three times.
# That mixes posting list (which should be doc IDs) with term frequency
# (which you compute later anyway).

terms = {}
for word in token1:
    if word not in terms:
       terms[word] = []
    terms[word].append('doc1')

print(terms)
# Out:
# {'test': ['doc1', 'doc1', 'doc1'], 'apple': ['doc1'], 'watermelon': ['doc1'], 'mango': ['doc1']}

# %%
# posting list token2
for word in token2:
    if word not in terms:
       terms[word] = []
    terms[word].append('doc2')

print(terms)
# Out:
# {'test': ['doc1', 'doc1', 'doc1'], 'apple': ['doc1'], 'watermelon': ['doc1'], 'mango': ['doc1'], "it's": ['doc2'], 'very': ['doc2'], 'hot': ['doc2'], 'today': ['doc2']}

# %%
# posting list token3
for word in token3:
    if word not in terms:
       terms[word] = []
    terms[word].append('doc3')

print(terms)
# Out:
# {'test': ['doc1', 'doc1', 'doc1'], 'apple': ['doc1', 'doc3'], 'watermelon': ['doc1', 'doc3'], 'mango': ['doc1'], "it's": ['doc2'], 'very': ['doc2'], 'hot': ['doc2', 'doc3'], 'today': ['doc2', 'doc3'], 'i': ['doc3'], 'drank': ['doc3'], 'and': ['doc3'], 'juice': ['doc3'], 'because': ['doc3'], 'it': ['doc3'], 'was': ['doc3']}

# %%
# Calculate TF for each term for each doc
tf_count = {}
for word in terms:
    tf_count[word] = {}
    tf_count[word]['doc1'] = token1.count(word)
    tf_count[word]['doc2'] = token2.count(word)
    tf_count[word]['doc3'] = token3.count(word)

print(tf_count)
# Out:
# {'test': {'doc1': 3, 'doc2': 0, 'doc3': 0}, 'apple': {'doc1': 1, 'doc2': 0, 'doc3': 1}, 'watermelon': {'doc1': 1, 'doc2': 0, 'doc3': 1}, 'mango': {'doc1': 1, 'doc2': 0, 'doc3': 0}, "it's": {'doc1': 0, 'doc2': 1, 'doc3': 0}, 'very': {'doc1': 0, 'doc2': 1, 'doc3': 0}, 'hot': {'doc1': 0, 'doc2': 1, 'doc3': 1}, 'today': {'doc1': 0, 'doc2': 1, 'doc3': 1}, 'i': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'drank': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'and': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'juice': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'because': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'it': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'was': {'doc1': 0, 'doc2': 0, 'doc3': 1}}

# %%
# Calculate IDF for each term
idf_count = {}
N = 3
for word in tf_count.keys():
  count = 0
  for doc in tf_count[word].keys():
        if tf_count[word][doc] > 0:
          count = count + 1
  idf_count[word] = math.log(N/count)

print(idf_count)
# Out:
# {'test': 1.0986122886681098, 'apple': 0.4054651081081644, 'watermelon': 0.4054651081081644, 'mango': 1.0986122886681098, "it's": 1.0986122886681098, 'very': 1.0986122886681098, 'hot': 0.4054651081081644, 'today': 0.4054651081081644, 'i': 1.0986122886681098, 'drank': 1.0986122886681098, 'and': 1.0986122886681098, 'juice': 1.0986122886681098, 'because': 1.0986122886681098, 'it': 1.0986122886681098, 'was': 1.0986122886681098}

# %%
# Calculate TF-IDF per term per doc
tf_idf = {}
for word in tf_count.keys():
  tf_idf[word] = {}
  for doc in tf_count[word].keys():
    tf_idf[word][doc] = tf_count[word][doc] * idf_count[word]

print(tf_idf)
# Out:
# {'test': {'doc1': 3.295836866004329, 'doc2': 0.0, 'doc3': 0.0}, 'apple': {'doc1': 0.4054651081081644, 'doc2': 0.0, 'doc3': 0.4054651081081644}, 'watermelon': {'doc1': 0.4054651081081644, 'doc2': 0.0, 'doc3': 0.4054651081081644}, 'mango': {'doc1': 1.0986122886681098, 'doc2': 0.0, 'doc3': 0.0}, "it's": {'doc1': 0.0, 'doc2': 1.0986122886681098, 'doc3': 0.0}, 'very': {'doc1': 0.0, 'doc2': 1.0986122886681098, 'doc3': 0.0}, 'hot': {'doc1': 0.0, 'doc2': 0.4054651081081644, 'doc3': 0.4054651081081644}, 'today': {'doc1': 0.0, 'doc2': 0.4054651081081644, 'doc3': 0.4054651081081644}, 'i': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'drank': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'and': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'juice': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'because': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'it': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'was': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}}

# %%
user_response = input("Enter query: ")
# Out:
# Enter query: test

# %%
# Tokenize query
user_response.split(" ")
# Out:
# ['test']

# %%
# Renamed 'sum' to 'query_scores_sum' to avoid shadowing built-in sum() function
query_scores_sum = {}
for word in user_response.split():
  if word in tf_idf.keys():
    for doc in tf_idf[word].keys():
      if doc not in query_scores_sum.keys():
        query_scores_sum[doc] = 0
      query_scores_sum[doc] = query_scores_sum[doc] + tf_idf[word][doc]

print(query_scores_sum)
# Out:
# {'doc1': 3.295836866004329, 'doc2': 0.0, 'doc3': 0.0}

# %%
# Sort descending using the updated variable name
sorted_doc = dict(sorted(query_scores_sum.items(), reverse=True))
print(sorted_doc)
# Out:
# {'doc3': 0.0, 'doc2': 0.0, 'doc1': 3.295836866004329}

# %% [markdown]
# CSV Clean Up TO BE USED LATER

# %%
df = pd.read_csv('data_processed.csv', on_bad_lines='skip', engine='python', encoding='latin1')

# %%
df = df.drop(columns=['source_id', 'source_name', 'author', 'url', 'url_to_image', 'published_at', 'category','content','full_content'], errors='ignore')

# %%
df["article_id"] = df["article_id"].astype(str)

article_lookup = df.set_index("article_id")[["title", "description"]].to_dict("index")

# %% [markdown]
# Manipulate Dataset

# %%
def tokenize(df):
    parsed_desc = {}

    for _, row in df.iterrows():
        article_id = str(row["article_id"])
        description = row["description"]

        if pd.notna(description):
            parsed_desc[article_id] = str(description).lower().split()
        else:
            parsed_desc[article_id] = []

    return parsed_desc

# %%
def build_inverted_index(parsed_desc):
    inverted_index = {}

    for document_id, document in parsed_desc.items():
        unique_terms = set(document)

        for term in unique_terms:
            if term not in inverted_index:
                inverted_index[term] = set()

            inverted_index[term].add(document_id)

    return inverted_index

# %%
parsed_desc = tokenize(df)
print(parsed_desc)
# Out:
# {'89541': ['un', 'secretary-general', 'antonio', 'guterres', 'urged', 'the', 'world', 'monday', 'to', '"stop', 'the', 'madness"', 'of', 'climate', 'change', 'as', 'he', 'visited', 'himalayan', 'regions', 'struggling', 'from', 'rapidly', 'melting', 'glaciers', 'to', 'witness', 'the', 'devastating', 'impact', 'of', 'the', 'phenomenon.'], '89542': ['[öêê½»áéçainer]', 'randeboo£¨¥é¥ó¥ç¥ö©`£©¤ç¤ï2023äê7ôâ18èõ(»ð)¤è¤ê¹«ê½web¥¹¥è¥¢¤ë¤æ2023', 'autumn', 'winter', '¥³¥ì¥¯¥·¥ç¥ó¤î°k\x89ó¤òé_ê¼¡£', '¥·©`¥º¥ó¥³¥ì¥¯¥·¥ç¥ó¤è¤·¤æ¡¢"nepal', 'handmade', 'ram', 'vest"¤è¡±nepal', 'handmade', 'ram', 'kn...'], '89543': ['un', 'secretary-general', 'antonio', 'guterres', 'urged', 'the', 'world', 'monday', 'to', '"stop', 'the', 'madness"', 'of', 'climate', 'change', 'as', 'he', 'visited', 'himalayan', 'regions', 'struggling', 'from', 'rapidly', 'melting', 'glaciers', 'to', 'witness', 'the', 'devastating', 'impact', 'of', 'the', 'phenomenon.', '"the', 'rooftops', 'of', 'the', 'world', 'are¡\xad'], '89545': ['ecologists', 'caution', 'against', 'the', 'adverse', 'effects', 'of', 'dam', 'construction', '¡ª', 'it', 'increases', 'the', 'volatility', 'of', 'rocks', 'in', 'the', 'himalayan', 'region.', "wednesday's", 'disaster', 'is', 'a', 'warning', 'to', 'take', 'such', 'caveats', 'seriously'], '89547': ['france', 'lost', '35', 'citizens,', 'thailand', '33,', 'us', '31,', 'ukraine', '21,', 'russia', '19,', 'uk', '12,', 'nepal', '10,', 'germany', '10,', 'argentina', '9,', 'canada', '6,', 'romania', '5,', 'portuguese', '4,', 'china', '4,', 'philippines', '4,', 'austria', '4', 'the', 'post', '200', 'foreigners,', 'dual', 'nationals', 'cut', 'down', 'in', 'hamas', 'assault.', 'here¡¯s', 'where', '¡\xad'], '89550': ['äá²´', '\x96»¨ùm\x94µ°ùèfãàôª½¨ôìò»×ùðâ\x99c\x88ö£¬ï£íû½å´ëíæ\x84óâãß[\x98i¡ª¡ªµ«êç\x99c\x88ö½¨ºãáë£¬', 's\x9b]óðèë\x81í¡£'], '89551': ['india,', 'the', 'first', 'non-arab', 'country', 'to', 'recognise', 'the', 'plo,', 'is', 'now', 'seen', 'closer', 'to', 'israel', 'and', 'its', 'biggest', 'benefactor,', 'the', 'us.'], '89555': ["india's", 'largest', 'airlines', 'have', 'ordered', 'nearly', '1,000', 'jets', 'this', 'year,', 'committing', 'tens', 'of', 'billions', 'of', 'dollars', 'to', 'a', 'spending', 'spree', 'that', 'is', 'unparalleled', 'in', 'aviation.'], '89556': ['hamas', 'fighters', 'have', 'escaped', 'back', 'to', 'gaza', 'with', 'dozens', 'of', 'captives,', 'including', 'women,', 'children', 'and', 'the', 'elderly,', 'after', 'an', 'unprecedented', 'attack', 'that', 'has', 'seen', 'at', 'least', '700', 'people', 'killed', 'in', 'israel,', 'followed', 'by', 'more', 'than', '400', 'in', 'the', 'palestinian', 'territories', 'after', 'retal¡\xad'], '89837': ['follow', 'live', 'text,', 'in-play', 'video', 'clips', 'and', 'radio', 'commentary', 'as', 'new', 'zealand', 'play', 'bangladesh', 'in', 'the', "men's", 'cricket', 'world', 'cup', '2023.'], '89557': ['a', 'himalayan', 'lake', 'fed', 'by', 'melting', 'ice', 'just', 'released', 'a', 'devastating', 'flood', 'in', 'northern', 'india.', 'thousands', 'of', 'other', 'unstable', 'lakes', 'are', 'getting', 'bigger', 'every', 'year.'], '89559': ['u.n.', 'secretary-general', 'antonio', 'guterres', 'made', 'an', 'impassioned', 'plea', 'for', 'peace', 'on', 'tuesday', 'from', 'a', 'nepalese', 'site', 'venerated', 'as', "buddha's", 'birthplace,', 'against', 'a', 'backdrop', 'of', 'conflict,', 'including', 'in', 'the', 'middle', 'east,', 'ukraine', 'and', 'sudan.', 'while', 'on', 'his', 'visit', 'to', 'nepal,', 'guterr¡\xad'], '89563': ['india', 'news:', 'new', 'delhi:', 'india', 'preferred', 'bangladesh', 'over', 'nepal', 'for', 'the', 'post', 'of', 'regional', 'director', 'of', 'world', 'health', 'organisation¡¯s', '(who)', 'southeast', 'asia', 'region', 'contribu.'], '89566': ['kuala', 'lumpur:', 'police', 'have', 'detained', '1,160', 'individuals', 'for', 'suspected', 'involvement', 'in', 'call', 'centre', 'scam', 'syndicates', 'in', 'the', 'first', 'nine', 'months', 'of', 'this', 'year.', 'read', ' ...

# %%
# TF Per Article Func -> basic ver first
# for each doc, count word
# for each word, tally
# probably same structure -> dictionary with doc, and then instead of list of words, list freq

def find_tf(desc):
  tf_per_doc = {}

  for document_id, document in desc.items():
      counts = Counter(document)
      total_words = len(document)

      if total_words == 0:
          tf_per_doc[document_id] = {}
          continue

      tf_per_doc[document_id] = {
          term: count / total_words
          for term, count in counts.items()
      }

  return tf_per_doc

# %%
# IDF Per Word Per Doc
def find_idf(desc):
    document_frequency = Counter()

    for document in desc.values():
        unique_terms = set(document)

        for term in unique_terms:
            document_frequency[term] += 1

    total_documents = len(desc)

    idf = {
        term: math.log(
            (total_documents - document_count + 0.5)
            / (document_count + 0.5)
            + 1
        )        for term, document_count in document_frequency.items()
    }

    return idf

# %%
def find_TFIDF(tf_per_doc, idf):
    tf_idf_by_doc = {}

    for document_id, document_tf in tf_per_doc.items():
        tf_idf_by_doc[document_id] = {}

        for term, tf_value in document_tf.items():
            tf_idf_by_doc[document_id][term] = (
                tf_value * idf[term]
            )

    return tf_idf_by_doc

, 'as': {'89653', '89707', '89645', '89636', '89541', '89623', '89699', '89690', '89671', '89543', '89683', '89883', '89837', '89698', '89662', '89578', '89602', '89656', '89559', '89644', '89613', '89672'}, 'devastating': {'89543', '89586', '89541', '89557'}, 'world': {'89563', '89690', '89543', '89688', '89570', '89644', '89883', '89701', '89578', '89577', '89837', '89541'}, 'phenomenon.': {'89543', '89541'}, 'glaciers': {'89543', '89541'}, 'melting': {'89543', '89541', '89557'}, 'secretary-general': {'89543', '89559', '89541', '89662'}, '"stop': {'89543', '89541'}, 'visited': {'89543', '89541'}, 'change': {'89543', '89690', '89541', '89570'}, 'madness"': {'89543', '89541'}, 'regions': {'89543', '89541'}, 'guterres': {'89543', '89559', '89541', '89662'}, 'from': {'89707', '89646', '89600', '89543', '89593', '89688', '89559', '89609', '89615', '89691', '89633', '89613', '89661', '89689', '89697', '89571', '89541', '89676'}, 'he': {'89543', '89653', '89541', '89662'}, 'autumn': {'89542'}, 'handmade': {'89542'}, '¥·©`¥º¥ó¥³¥ì¥¯¥·¥ç¥ó¤è¤·¤æ¡¢"nepal': {'89542'}, '[öêê½»áéçainer]': {'89542'}, 'winter': {'89542'}, 'randeboo£¨¥é¥ó¥ç¥ö©`£©¤ç¤ï2023äê7ôâ18èõ(»ð)¤è¤ê¹«ê½web¥¹¥è¥¢¤ë¤æ2023': {'89542'}, '¥³¥ì¥¯¥·¥ç¥ó¤î°k\x89ó¤òé_ê¼¡£': {'89542'}, 'kn...': {'89542'}, 'vest"¤è¡±nepal': {'89542'}, 'ram': {'89542'}, '"the': {'89543'}, 'rooftops': {'89543'}, 'are¡\xad': {'89543'}, '¡ª': {'89545'}, 'is': {'89659', '89628', '89600', '89616', '89555', '89639', '89693', '89702', '89551', '89691', '89701', '89638', '89617', '89662', '89545', '89676'}, 'ecologists': {'89545'}, 'increases': {'89545'}, 'adverse': {'89545'}, 'dam': {'89545', '89698'}, "wednesday's": {'89545'}, 'caveats': {'89545'}, 'a': {'89653', '89707', '89621', '89574', '89601', '89688', '89636', '89610', '89701', '89697', '101939', '89699', '89690', '89569', '89616', '89714', '89702', '40639', '89683', '89570', '89648', '89654', '89883', '89581', '89670', '89643', '89646', ...

# %%
user_response = input("Enter query: ")
# Tokenize query
parsed_query = user_response.split(" ")
print(parsed_query)
# Out:
# Enter query: How to invest in stocks
# ['How', 'to', 'invest', 'in', 'stocks']

# %%
# Find query term from parsed_desc
# Store documents in a dictionary
def find_query_term(inverted_index, parsed_query):
  query_terms = {}

  for term in parsed_query:
    if term in inverted_index:
      query_terms[term] = inverted_index[term]

  return query_terms

# %%
query_terms = find_query_term(inverted_index, parsed_query)
print(query_terms)
# Out:
# {'to': {'89707', '89574', '89639', '89636', '89610', '89680', '89615', '89701', '89631', '89541', '89659', '89671', '89543', '89714', '89702', '89570', '89654', '89584', '89556', '89677', '89597', '89646', '89555', '89647', '89587', '89698', '89617', '89662', '89578', '89545', '89676', '89559', '89644', '89551', '89651', '89633', '89613', '89668', '89634', '89672', '89689'}, 'in': {'89653', '89707', '89621', '89574', '89639', '89636', '89610', '89680', '89701', '89697', '89566', '89631', '89623', '89547', '89659', '89690', '89699', '89671', '89616', '89714', '89693', '89657', '89673', '89683', '89570', '89648', '89654', '89584', '89670', '89556', '89694', '89837', '89646', '89555', '89593', '89675', '89647', '89587', '89609', '89665', '89669', '89698', '89638', '89557', '89662', '89634', '89592', '89545', '89640', '89656', '89559', '89651', '89691', '89661', '89577', '89672', '89689'}}

# %%
# BM25 Steps:
# 1. Checks how many times each term appears.
# 2. Gives rarer terms more weight.
# 3. Reduces the benefit of repeated terms.
# 4. Adjusts for document length.
# 5. Adds the scores for all query terms.
# Use helper method for calculation
def countAppearance(parseddesc, parsedquery):
    appearance = {}

    for articleid, tokens in parseddesc.items():
        for term in parsedquery:
            count = tokens.count(term)

            if count > 0:
                if articleid not in appearance:
                    appearance[articleid] = {}
                appearance[articleid][term] = count

    return appearance

# %%
def BM25(parsedquery, parseddesc, idf, k1=1.5, b=0.75):
    doclengths = {
        documentid: len(document)
        for documentid, document in parseddesc.items()
    }

    if not doclengths:
        return {}

    avgdl = sum(doclengths.values()) / len(doclengths)

    appearance = countAppearance(parseddesc, parsedquery)

    scores = {docid: 0.0 for docid in appearance}

    for docid, termcounts in appearance.items():
        doclen = doclengths.get(docid, 0)
        if doclen == 0:
            continue

        for term, tf in termcounts.items():
            if term not in idf:
                continue

            idft = idf[term]
            numerator = tf * (k1 + 1)
            denominator = tf + k1 * (1 - b + b * (doclen / avgdl))

            scores[docid] += idft * (numerator / denominator)

    return scores

# %%
# Func Top K
def topK(sorted_doc, df, top_k, label="BM25 score"):
    article_lookup = (
        df.assign(article_id=df["article_id"].astype(str))
          .set_index("article_id")[["title", "description"]]
          .to_dict("index")
    )

    results = list(sorted_doc.items())[:top_k]

    if not results:
        print("No results found.")
        return

    for rank, (article_id, score) in enumerate(results, start=1):
        article = article_lookup.get(str(article_id), {})

        print(f"Rank {rank}:")
        print(f"Title: {article.get('title', 'N/A')}")
        print(f"Description: {article.get('description', 'N/A')}")
        print(f"{label}: {score:.4f}")
        print()

# %%
raw_tokens = tokenize(df)
# print(countAppearance(raw_tokens, parsed_query))

bm25scores = BM25(parsed_query, raw_tokens, idf)
sorteddoc = dict(sorted(bm25scores.items(), key=lambda x: x[1], reverse=True))
topK(sorteddoc, df, 5, label="BM25 score")
# Out:
# Rank 1:
# Title: Second woman declared dead on Tibet peak
# Description: BEIJING - A second woman hoping to be the first American female climber to scale all of the world¡¯s 8,000-metre (26,246 feet) mountains has been declared dead on a remote peak in Tibet, according to her family.
# BM25 score: 1.9468
#
# Rank 2:
# Title: 5 Civilians Dead, 23 Soldiers Missing After Flooding in India
# Description: Five people have died and 23 soldiers are missing after flash flooding Wednesday in India's Lachen Valley in the northeastern state of Sikkim, according to army officials.?
#
#
# The flood, caused by heavy rainfall, blocked the main highway to Sikkim's capital, G¡­
# BM25 score: 1.8965
#
# Rank 3:
# Title: Indian rescue copters are flying into region where flood washed out bridges and killed at least 52
# Description: Air force helicopters have been able to land to rescue people in India¡¯s Himalayan northeast after a 6-year-old hydroelectric dam cracked open last week in intense rain, flooding a valley with glacial lake water and washing away bridges and homes as thousands¡­
# BM25 score: 1.8791
#
# Rank 4:
# Title: Bar Council moves HC against its ruling on enrolling South Korean as advocate
# Description: The Bar Council of India has approached the Delhi High Court to challenge a previous direction to process the enrolment of a South Korean national as an advocate. The BCI argued that foreign lawyers are not allowed to practice in Indian courts, and allowing t¡­
# BM25 score: 1.8155
#
# Rank 5:
# Title: AI of tiger: Tiny camera protects people
# Description: Tiger populations are on the rise in the jungles of India and Nepal and the predators are roaming ever closer to villages, sparking a race among conservationists to find ways of avoiding conflict.
# BM25 score: 1.8072

# %%
# TBD
# lower/uppercase issues, punctuations, etc -> add handling for it.
# encoder in latin may be the issue also

# %% [markdown]
# # **EMBEDDING**
#
#
# ```
#                       OFFLINE (once, before any query)
#                      ─────────────────────────────────
# each document's description
#          ↓
#    embedding model
#          ↓
#    one vector per doc  ──→  store in a matrix (100 × 384)
#
#
#                      ONLINE (per query)
#                      ──────────────────
# query string
#          ↓
#    same embedding model
#          ↓
#    one query vector  (1 × 384)
#          ↓
#    cosine similarity against every doc vector
#          ↓
#    rank by similarity → top K
# ```

# %%
# import Gemini embedding model
# pip install google-genai

import google.genai as genai

client = genai.Client(api_key="YOUR-API-KEY")

# %%
# collect descs -> lists

doc_ids = []
doc_texts = []

for _, row in df.iterrows():
    doc_ids.append(str(row["article_id"]))

    desc = row["description"]
    if pd.notna(desc):
        doc_texts.append(str(desc))
    else:
        doc_texts.append("")

print(f"Collected {len(doc_texts)} descriptions")
print(f"Example: {doc_texts[0][:100]}...")
# Out:
# Collected 100 descriptions
# Example: UN Secretary-General Antonio Guterres urged the world Monday to "stop the madness" of climate change...

# %%
# Embed documents

MODELS = ["gemini-embedding-001", "gemini-embedding-002"]

used_model = None

def embed_with_fallback(texts):
    global used_model

    for model_name in MODELS:
        try:
            result = client.models.embed_content(
                model=model_name,
                contents=texts
            )
            used_model = model_name
            print(f"Embedded {len(texts)} text(s) using {model_name}")
            return np.array([e.values for e in result.embeddings])

        except Exception as e:
            print(f"{model_name} failed: {e}")
            print("Trying next model...")

    raise RuntimeError("All embedding models failed")

doc_embeddings = embed_with_fallback(doc_texts)

print(f"Shape: {doc_embeddings.shape}")
# Out:
# Embedded 100 text(s) using gemini-embedding-001
# Shape: (100, 3072)

# %%
# Embed query

query_result = client.models.embed_content(
    model="gemini-embedding-001",
    contents=[user_response]
)

query_embedding = np.array([query_result.embeddings[0].values])

print(f"Query embedded using: {used_model}")
# Out:
# Query embedded using: gemini-embedding-001

# %%
# Check cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

scores = cosine_similarity(query_embedding, doc_embeddings)[0]

# Build a dict of {article_id: score} — same shape topK expects
embedding_scores = {}
for i in range(len(doc_ids)):
    embedding_scores[doc_ids[i]] = scores[i]

# Sort descending by score
sorted_embedding = dict(sorted(embedding_scores.items(), key=lambda x: x[1], reverse=True))

# Reuse your existing topK function
topK(sorted_embedding, df, 10, label="Cosine sim")
# Out:
# Rank 1:
# Title: ?????? ??? ???? ??????, ???? ??????...????? ?????????!
# Description: ??????-?????? ???? ????? ???? ??? ?? ????? ?? ??? ???? ????? ??? ??. ?? ??-?? ???? ??? ??? ????? ??? ??. ???? ?????? ????? ???? ??? ??, ?? ????? ?? ?????? ????? ????? ?? ??? ??.
