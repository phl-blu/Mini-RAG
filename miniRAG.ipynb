# %%
# import numpy
# import math
# import matplotlib
# import pandas
import numpy as np
import math
import matplotlib as plt
import pandas as pd
from collections import Counter

# %%
# Declare the 2 vectors
A = [2,3]
B = [5,1]

# %%
print(A)
# Out:
# [2, 3]

# %%
print(B)
# Out:
# [5, 1]

# %%
# calculate dot product

# if A contains mor elements than B, then length = A; else length = B
if A > B:
  length = len(A) #length A
else:
  length = len(B) #length B

# Renamed 'sum' to 'dot_product_sum' to avoid shadowing built-in sum()
dot_product_sum = 0
for i in range(length):
  dot_product_sum = dot_product_sum + A[i] * B[i]

# %%
# print summ
print(dot_product_sum)
# Out:
# 13

# %%
# calculate cosine similarity
# cos similarity = dot product /  ||A|| * ||B||

lengthA = math.sqrt(A[0]**2 + A[1]**2) # ** is exponent
lengthB = math.sqrt(B[0]**2 + B[1]**2)


cosAB = dot_product_sum / (lengthA*lengthB)

print(cosAB)
# Out:
# 0.7071067811865476

# %%
# calculate euclidean distance
euclidean = math.sqrt((B[0] - A[0])**2 + (B[1] - A[1])**2)
print(euclidean)
# Out:
# 3.605551275463989

# %% [markdown]
# Testing TF Concept

# %%
doc1 = "test test test apple watermelon mango"
doc2 = "it's very hot today"
doc3 = "i drank apple and watermelon juice today because it was hot"

# cut into substrings first aka tokenization
token1 = doc1.split(" ")
token2 = doc2.split(" ")
token3 = doc3.split(" ")

# %%
# posting list token1
# This gives "test": ["doc1", "doc1", "doc1"] when test appears three times.
# That mixes posting list (which should be doc IDs) with term frequency
# (which you compute later anyway).

terms = {}
for word in token1:
    if word not in terms:
       terms[word] = []
    terms[word].append('doc1')

print(terms)
# Out:
# {'test': ['doc1', 'doc1', 'doc1'], 'apple': ['doc1'], 'watermelon': ['doc1'], 'mango': ['doc1']}

# %%
# posting list token2
for word in token2:
    if word not in terms:
       terms[word] = []
    terms[word].append('doc2')

print(terms)
# Out:
# {'test': ['doc1', 'doc1', 'doc1'], 'apple': ['doc1'], 'watermelon': ['doc1'], 'mango': ['doc1'], "it's": ['doc2'], 'very': ['doc2'], 'hot': ['doc2'], 'today': ['doc2']}

# %%
# posting list token3
for word in token3:
    if word not in terms:
       terms[word] = []
    terms[word].append('doc3')

print(terms)
# Out:
# {'test': ['doc1', 'doc1', 'doc1'], 'apple': ['doc1', 'doc3'], 'watermelon': ['doc1', 'doc3'], 'mango': ['doc1'], "it's": ['doc2'], 'very': ['doc2'], 'hot': ['doc2', 'doc3'], 'today': ['doc2', 'doc3'], 'i': ['doc3'], 'drank': ['doc3'], 'and': ['doc3'], 'juice': ['doc3'], 'because': ['doc3'], 'it': ['doc3'], 'was': ['doc3']}

# %%
# Calculate TF for each term for each doc
tf_count = {}
for word in terms:
    tf_count[word] = {}
    tf_count[word]['doc1'] = token1.count(word)
    tf_count[word]['doc2'] = token2.count(word)
    tf_count[word]['doc3'] = token3.count(word)

print(tf_count)
# Out:
# {'test': {'doc1': 3, 'doc2': 0, 'doc3': 0}, 'apple': {'doc1': 1, 'doc2': 0, 'doc3': 1}, 'watermelon': {'doc1': 1, 'doc2': 0, 'doc3': 1}, 'mango': {'doc1': 1, 'doc2': 0, 'doc3': 0}, "it's": {'doc1': 0, 'doc2': 1, 'doc3': 0}, 'very': {'doc1': 0, 'doc2': 1, 'doc3': 0}, 'hot': {'doc1': 0, 'doc2': 1, 'doc3': 1}, 'today': {'doc1': 0, 'doc2': 1, 'doc3': 1}, 'i': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'drank': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'and': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'juice': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'because': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'it': {'doc1': 0, 'doc2': 0, 'doc3': 1}, 'was': {'doc1': 0, 'doc2': 0, 'doc3': 1}}

# %%
# Calculate IDF for each term
idf_count = {}
N = 3
for word in tf_count.keys():
  count = 0
  for doc in tf_count[word].keys():
        if tf_count[word][doc] > 0:
          count = count + 1
  idf_count[word] = math.log(N/count)

print(idf_count)
# Out:
# {'test': 1.0986122886681098, 'apple': 0.4054651081081644, 'watermelon': 0.4054651081081644, 'mango': 1.0986122886681098, "it's": 1.0986122886681098, 'very': 1.0986122886681098, 'hot': 0.4054651081081644, 'today': 0.4054651081081644, 'i': 1.0986122886681098, 'drank': 1.0986122886681098, 'and': 1.0986122886681098, 'juice': 1.0986122886681098, 'because': 1.0986122886681098, 'it': 1.0986122886681098, 'was': 1.0986122886681098}

# %%
# Calculate TF-IDF per term per doc
tf_idf = {}
for word in tf_count.keys():
  tf_idf[word] = {}
  for doc in tf_count[word].keys():
    tf_idf[word][doc] = tf_count[word][doc] * idf_count[word]

print(tf_idf)
# Out:
# {'test': {'doc1': 3.295836866004329, 'doc2': 0.0, 'doc3': 0.0}, 'apple': {'doc1': 0.4054651081081644, 'doc2': 0.0, 'doc3': 0.4054651081081644}, 'watermelon': {'doc1': 0.4054651081081644, 'doc2': 0.0, 'doc3': 0.4054651081081644}, 'mango': {'doc1': 1.0986122886681098, 'doc2': 0.0, 'doc3': 0.0}, "it's": {'doc1': 0.0, 'doc2': 1.0986122886681098, 'doc3': 0.0}, 'very': {'doc1': 0.0, 'doc2': 1.0986122886681098, 'doc3': 0.0}, 'hot': {'doc1': 0.0, 'doc2': 0.4054651081081644, 'doc3': 0.4054651081081644}, 'today': {'doc1': 0.0, 'doc2': 0.4054651081081644, 'doc3': 0.4054651081081644}, 'i': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'drank': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'and': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'juice': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'because': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'it': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}, 'was': {'doc1': 0.0, 'doc2': 0.0, 'doc3': 1.0986122886681098}}

# %%
user_response = input("Enter query: ")
# Out:
# Enter query: test

# %%
# Tokenize query
user_response.split(" ")
# Out:
# ['test']

# %%
# Renamed 'sum' to 'query_scores_sum' to avoid shadowing built-in sum() function
query_scores_sum = {}
for word in user_response.split():
  if word in tf_idf.keys():
    for doc in tf_idf[word].keys():
      if doc not in query_scores_sum.keys():
        query_scores_sum[doc] = 0
      query_scores_sum[doc] = query_scores_sum[doc] + tf_idf[word][doc]

print(query_scores_sum)
# Out:
# {'doc1': 3.295836866004329, 'doc2': 0.0, 'doc3': 0.0}

# %%
# Sort descending using the updated variable name
sorted_doc = dict(sorted(query_scores_sum.items(), reverse=True))
print(sorted_doc)
# Out:
# {'doc3': 0.0, 'doc2': 0.0, 'doc1': 3.295836866004329}

# %% [markdown]
# CSV Clean Up TO BE USED LATER

# %%
df = pd.read_csv('data.csv', on_bad_lines='skip', engine='python', encoding='latin1')

# %%
df = df.drop(columns=['source_id', 'source_name', 'author', 'url', 'url_to_image', 'published_at', 'category','content','full_content'], errors='ignore')

# %%
df["article_id"] = df["article_id"].astype(str)

# Drop duplicates to ensure the index is unique for the dictionary conversion
article_lookup = df.drop_duplicates(subset="article_id").set_index("article_id")[["title", "description"]].to_dict("index")

# %%
import re

def is_english(text):
    if not isinstance(text, str) or len(text.strip()) == 0:
        return False
    ascii_chars = len(re.findall(r'[a-zA-Z]', text))
    return ascii_chars / max(len(text), 1) > 0.5

df = df[df['description'].apply(is_english)].reset_index(drop=True)

# %% [markdown]
# Manipulate Dataset

# %%
def tokenize(df):
    parsed_desc = {}

    for _, row in df.iterrows():
        article_id = str(row["article_id"])
        description = row["description"]

        if pd.notna(description):
            parsed_desc[article_id] = str(description).lower().split()
        else:
            parsed_desc[article_id] = []

    return parsed_desc

# %%
def build_inverted_index(parsed_desc):
    inverted_index = {}

    for document_id, document in parsed_desc.items():
        unique_terms = set(document)

        for term in unique_terms:
            if term not in inverted_index:
                inverted_index[term] = set()

            inverted_index[term].add(document_id)

    return inverted_index

# %%
parsed_desc = tokenize(df)

# %%
# TF Per Article Func -> basic ver first
# for each doc, count word
# for each word, tally
# probably same structure -> dictionary with doc, and then instead of list of words, list freq

def find_tf(desc):
  tf_per_doc = {}

  for document_id, document in desc.items():
      counts = Counter(document)
      total_words = len(document)

      if total_words == 0:
          tf_per_doc[document_id] = {}
          continue

      tf_per_doc[document_id] = {
          term: count / total_words
          for term, count in counts.items()
      }

  return tf_per_doc

# %%
# IDF Per Word Per Doc
def find_idf(desc):
    document_frequency = Counter()

    for document in desc.values():
        unique_terms = set(document)

        for term in unique_terms:
            document_frequency[term] += 1

    total_documents = len(desc)

    idf = {
        term: math.log(
            (total_documents - document_count + 0.5)
            / (document_count + 0.5)
            + 1
        )        for term, document_count in document_frequency.items()
    }

    return idf

# %%
def find_TFIDF(tf_per_doc, idf):
    tf_idf_by_doc = {}

    for document_id, document_tf in tf_per_doc.items():
        tf_idf_by_doc[document_id] = {}

        for term, tf_value in document_tf.items():
            tf_idf_by_doc[document_id][term] = (
                tf_value * idf[term]
            )

    return tf_idf_by_doc

# %%
inverted_index = build_inverted_index(parsed_desc)
tf_per_doc = find_tf(parsed_desc)
idf = find_idf(parsed_desc)
parsed_desc = find_TFIDF(tf_per_doc, idf)

# %%
user_response = input("Enter query: ")
# Tokenize query
parsed_query = user_response.lower().split(" ")
# Out:
# Enter query: what's the current stock market like and what should I invest in?

# %%
# Find query term from parsed_desc
# Store documents in a dictionary
def find_query_term(inverted_index, parsed_query):
  query_terms = {}

  for term in parsed_query:
    if term in inverted_index:
      query_terms[term] = inverted_index[term]

  return query_terms

# %%
query_terms = find_query_term(inverted_index, parsed_query)
print(query_terms)
# Out:
# {"what's": {'23706', '115902', '12489', '162483', '27594', '129163', '16533', '17058', '35971', '35206', '92755', '114218', '114575', '26501', '68268', '36844', '44156', '100905', '21735', '19484', '5016', '97110', '65904', '26066', '19025', '21552', '48911', '95572', '73518', '16537', '16696', '118016', '20498', '25365', '39517', '98603', '35579', '104737', '59664', '40875', '72079', '33765', '124069', '95060', '93007', '126082', '26761', '104344', '92240', '111347', '70442', '37652', '30763', '96544', '48928', '75374', '68557', '130454', '28845', '44454', '165130', '33574', '76806', '110132', '105074', '20223', '70391', '93521', '43855', '65598', '9775', '94657', '116430', '44328', '16758', '35793', '122270', '121298', '95013', '12475', '76538', '32515', '26007', '115313', '2396', '23476', '31810', '52489', '43702', '43385', '18602', '21252'}, 'the': {'16680', '48590', '54713', '29843', '72126', '100187', '42114', '72258', '123918', '78031', '18899', '71524', '103380', '99790', '118912', '128857', '164778', '64415', '6794', '95574', '134308', '63205', '124305', '44951', '76597', '20273', '18189', '4962', '68582', '102264', '26873', '119255', '143794', '36825', '26171', '12377', '27337', '237705', '132953', '26959', '116961', '101416', '134537', '100063', '107260', '91203', '55550', '110808', '98135', '29675', '6781', '12271', '237583', '116590', '116266', '22638', '33230', '103450', '73541', '108756', '12735', '67471', '25692', '129153', '48751', '94993', '3835', '125028', '125595', '94337', '153028', '11298', '118171', '31452', '48334', '66119', '157133', '175632', '22106', '119892', '149758', '128758', '101622', '11952', '73352', '115762', '111764', '68642', '16769', '143792', '37011', '90309', '102356', '133458', '98671', '137844', '92645', '153409', '38433', '123979', '95912', '14132', '121665', '205372', '33191', '15088', '31077', '80143', '126036', '27926', '4770', '4950', '61154', '35622', '18706', '35231', '90985', '54412', '94208', '61312', '156685', '91204', '4876', '122801', '105143', '53553', '23095', '55465', '217473', '33416', '45084', '121176', '121160', '30222', '52499', '94751', '153362', '42543', '70391', '91368', '120045', '130594', '98183', '118970', '121627', '113997', '4704', '20901', '118585', '122036', '13417', '97107', '22435', '10637', '90042', '13533', '48835', '218836', '24053', '42460', '18311', '44779', '32451', '35662', '134836', '50908', '28927', '14079', '79232', '207515', '99910', '42511', '26181', '134077', '13798', '121271', '121809', '143610', '161225', '33261', '53273', '23288', '216357', '34119', '74897', '116454', '236658', '100068', '8334', '27407', '33831', '127550', '208075', '173703', '156369', '101673', '100281', '101996', '92436', '6219', '62392', '80609', '140851', '201870', '63567', '108327', '67935', '3004', '9036', '217671', '19083', '97403', '96698', '90794', '19783', '93628', '118841', '149509', '19381', '164746', '26103', '54597', '134296', '66219', '70511', '36349', '105813', '127558', '132935', '104116', '44619', '55923', '96528', '7031', '31688', '108488', '78311', '6253', '94166', '8648', '14231', '48896', '66026', '168804', '136482', '111413', '72829', '16551', '31519', '236411', '90317', '104279', '115516', '53835', '62434', '217820', '112919', '49153', '53724', '14155', '102357', '75068', '9625', '96029', '39403', '37602', '94907', '26738', '222241', '61951', '9438', '46210', '66162', '44975', '130292', '67965', '72671', '30403', '22940', '21053', '30687', '125462', '19584', '130592', '112269', '16382', '93633', '66683', '123156', '72764', '26068', '79432', '217813', '38669', '58889', '118372', '206851', '50072', '119024', '8733', '131308', '33661', '3823', '23583', '8236', '232405', '35276', '106749', '126647', '128248', '16291', '38232', '55468', '149957', '95804', '10511', '68937', '79561', '20099', '36905', '69025', '90004', '65621', '143446', '151814', '15073', '107091', '28929', '35183', '119004', '120860', '106763', '108773', '225704', '103559', '120324', '11 ...

# %%
# BM25 Steps:
# 1. Checks how many times each term appears.
# 2. Gives rarer terms more weight.
# 3. Reduces the benefit of repeated terms.
# 4. Adjusts for document length.
# 5. Adds the scores for all query terms.
# Use helper method for calculation
def countAppearance(parseddesc, parsedquery):
    appearance = {}

    for articleid, tokens in parseddesc.items():
        for term in parsedquery:
            count = tokens.count(term)

            if count > 0:
                if articleid not in appearance:
                    appearance[articleid] = {}
                appearance[articleid][term] = count

    return appearance

# %%
def BM25(parsedquery, parseddesc, idf, k1=1.5, b=0.75):
    doclengths = {
        documentid: len(document)
        for documentid, document in parseddesc.items()
    }

    if not doclengths:
        return {}

    avgdl = sum(doclengths.values()) / len(doclengths)

    appearance = countAppearance(parseddesc, parsedquery)

    scores = {docid: 0.0 for docid in appearance}

    for docid, termcounts in appearance.items():
        doclen = doclengths.get(docid, 0)
        if doclen == 0:
            continue

        for term, tf in termcounts.items():
            if term not in idf:
                continue

            idft = idf[term]
            numerator = tf * (k1 + 1)
            denominator = tf + k1 * (1 - b + b * (doclen / avgdl))

            scores[docid] += idft * (numerator / denominator)

    return scores

# %%
def topK(sorted_doc, df, top_k):
    article_lookup = (
        df.assign(article_id=df["article_id"].astype(str))
          .drop_duplicates(subset=["article_id"])
          .set_index("article_id")[["title", "description"]]
          .to_dict("index")
    )
    results = []
    for article_id, score in list(sorted_doc.items())[:top_k]:
        article = article_lookup.get(str(article_id), {})
        results.append((article_id, score, article.get("title", "N/A"), article.get("description", "N/A")))
    return results

# %%
# Func Print Top K
def printTopK(results, label="BM25 score"):
    if not results:
        print("No results found.")
        return
    for rank, (article_id, score, title, desc) in enumerate(results, 1):
        print(f"Rank {rank}:")
        print(f"Article ID: {article_id}")
        print(f"Title: {title}")
        print(f"Description: {desc}")
        print(f"{label}: {score:.4f}")
        print()

# %%
raw_tokens = tokenize(df)
# print(countAppearance(raw_tokens, parsed_query))

bm25scores = BM25(parsed_query, raw_tokens, idf)
sorteddoc = dict(sorted(bm25scores.items(), key=lambda x: x[1], reverse=True))
bm25topK = topK(sorteddoc, df, 5)
printTopK(bm25topK, "BM25 score")
# Out:
# Rank 1:
# Article ID: 134121
# Title: What If This Time is Different For the Stock Market?
# Description: I appreciate Benâs long-term view of stock market corrections but what if this time is different? What are the stats when the Fed is actively offloading trillions of assets AND raising rates? What if this cycle is an anomaly and should be treated as such? Thiâ¦
# BM25 score: 19.4242
#
# Rank 2:
# Article ID: 44248
# Title: Inside An NFT Collectorâs Mind
# Description: What motivates buyers to invest in NFTs during a bear market and how their approach to collecting has changed.
# BM25 score: 17.6811
#
# Rank 3:
# Article ID: 33254
# Title: 33 Memes to Keep Coherent Thoughts at Bay
# Description: I don't know about you, but I often get fed up with thinking. It's so annoying that we need to spend so much of our day using our conscious mind. What should I have for breakfast? What signoff should I use for that email? What do I have time to do at the weekâ¦
# BM25 score: 16.8965
#
# Rank 4:
# Article ID: 27257
# Title: 3 tips experts gave me to pull money out of the stock market without getting slammed by taxes
# Description: During the pandemic, I recklessly bought stocks. I want to sell most of them before the year ends, so I asked the experts what I should do.
# BM25 score: 16.0734
#
# Rank 5:
# Article ID: 100905
# Title: XRP's Market Path: Golden Cross, Volume Drop and Lack of Clarity, What's Next?
# Description: XRP's Market Path: Golden Cross, Volume Drop and Lack of Clarity, What's Next?
# BM25 score: 15.0234

# %%
# TBD
# lower/uppercase issues, punctuations, etc -> add handling for it.
# encoder in latin may be the issue also

# %% [markdown]
# # **EMBEDDING**
#
#
# ```
#                       OFFLINE (once, before any query)
#                      ─────────────────────────────────
# each document's description
#          ↓
#    embedding model
#          ↓
#    one vector per doc  ──→  store in a matrix (100 × 384)
#
#
#                      ONLINE (per query)
#                      ──────────────────
# query string
#          ↓
#    same embedding model
#          ↓
#    one query vector  (1 × 384)
#          ↓
#    cosine similarity against every doc vector
#          ↓
#    rank by similarity → top K
# ```

# %%
# Gemini
import os
from google.colab import userdata
import google.genai as genai

# Securely fetch the key from Colab Secrets
api_key = userdata.get('gemini-key')

# Initialize the client (this replaces genai.configure)
client = genai.Client(api_key=api_key)

# %%
# Openrouter
import time
from openai import OpenAI
import numpy as np

# Nemotron client (set up once)
open_key = userdata.get('openrouter-key')
openrouter_client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=open_key
)

# %%
# collect descs -> lists

doc_ids = []
doc_texts = []

for _, row in df.iterrows():
    doc_ids.append(str(row["article_id"]))

    desc = row["description"]
    if pd.notna(desc):
        doc_texts.append(str(desc))
    else:
        doc_texts.append("")

print(f"Collected {len(doc_texts)} descriptions")
print(f"Example: {doc_texts[0][:100]}...")
# Out:
# Collected 68682 descriptions
# Example: UN Secretary-General Antonio Guterres urged the world Monday to "stop the madness" of climate change...

# %%
import time

MODELS = ["gemini-embedding-001"]

used_model = None
CACHE_FILE = "doc_embeddings.npy"
MODEL_CACHE = "used_model.txt"

def embed_with_fallback(texts, batch_size=100):
    global used_model

    for model_name in MODELS:
        for attempt in range(3):
            try:
                all_embeddings = []
                for i in range(0, len(texts), batch_size):
                    batch = texts[i : i + batch_size]
                    result = client.models.embed_content(
                        model=model_name,
                        contents=batch
                    )
                    all_embeddings.extend([e.values for e in result.embeddings])

                used_model = model_name
                print(f"Embedded {len(texts)} text(s) using {model_name}")
                return np.array(all_embeddings)

            except Exception as e:
                error_str = str(e)
                if "429" in error_str and attempt < 2:
                    print(f"Rate limited. Waiting 45s (attempt {attempt + 1}/3)...")
                    time.sleep(45)
                else:
                    print(f"{model_name} failed: {e}")
                    break

    print("Gemini failed. Falling back to Nemotron...")
    try:
        all_embeddings = []
        for i in range(0, len(texts), batch_size):
            batch = texts[i : i + batch_size]
            print(f"  Embedding batch {i//batch_size + 1}/{(len(texts)-1)//batch_size + 1}...")
            response = openrouter_client.embeddings.create(
              model="nvidia/nemotron-3-embed-1b:free",
              input=batch,
              encoding_format="float"
            )
            all_embeddings.extend([e.embedding for e in response.data])

        used_model = "nemotron-3-embed-1b"
        print(f"Embedded {len(texts)} text(s) using Nemotron (OpenRouter)")
        return np.array(all_embeddings)

    except Exception as e:
        print(f"Nemotron failed: {e}")

    raise RuntimeError("All embedding models failed")


# Load from cache or embed fresh
if os.path.exists(CACHE_FILE) and os.path.exists(MODEL_CACHE):
    doc_embeddings = np.load(CACHE_FILE)
    with open(MODEL_CACHE, "r") as f:
        used_model = f.read().strip()
    print(f"Loaded cached embeddings: {doc_embeddings.shape} (model: {used_model})")
else:
    doc_embeddings = embed_with_fallback(doc_texts,100)
    np.save(CACHE_FILE, doc_embeddings)
    with open(MODEL_CACHE, "w") as f:
        f.write(used_model)
    print(f"Saved embeddings: {doc_embeddings.shape} (model: {used_model})")
# Out:
# Rate limited. Waiting 45s (attempt 1/3)...
# Rate limited. Waiting 45s (attempt 2/3)...
# gemini-embedding-001 failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 1000, model: gemini-embedding-1.0\nPlease retry in 4.003528316s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/embed_content_free_tier_requests', 'quotaId': 'EmbedContentRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-embedding-1.0'}, 'quotaValue': '1000'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Gemini failed. Falling back to Nemotron...
#   Embedding batch 1/687...
#   Embedding batch 2/687...
#   Embedding batch 3/687...
#   Embedding batch 4/687...
#   Embedding batch 5/687...
#   Embedding batch 6/687...
#   Embedding batch 7/687...
#   Embedding batch 8/687...
#   Embedding batch 9/687...
#   Embedding batch 10/687...
#   Embedding batch 11/687...
#   Embedding batch 12/687...
#   Embedding batch 13/687...
#   Embedding batch 14/687...
#   Embedding batch 15/687...
#   Embedding batch 16/687...
#   Embedding batch 17/687...
#   Embedding batch 18/687...
#   Embedding batch 19/687...
#   Embedding batch 20/687...
#   Embedding batch 21/687...
#   Embedding batch 22/687...
#   Embedding batch 23/687...
#   Embedding batch 24/687...
#   Embedding batch 25/687...
#   Embedding batch 26/687...
#   Embedding batch 27/687...
#   Embedding batch 28/687...
#   Embedding batch 29/687...
#   Embedding batch 30/687...
#   Embedding batch 31/687...
#   Embedding batch 32/687...
#   Embedding batch 33/687...
#   Embedding batch 34/687...
#   Embedding batch 35/687...
#   Embedding batch 36/687...
#   Embedding batch 37/687...
#   Embedding batch 38/687...
#   Embedding batch 39/687...
#   Embedding batch 40/687...
#   Embedding batch 41/687...
#   Embedding batch 42/687...
#   Embedding batch 43/687...
#   Embedding batch 44/687...
#   Embedding batch 45/687...
#   Embedding batch 46/687...
#   Embedding batch 47/687...
#   Embedding batch 48/687...
#   Embedding batch 49/687...
#   Embedding batch 50/687...
#   Embedding batch 51/687...
#   Embedding batch 52/687...
#   Embedding batch 53/687...
#   Embedding batch 54/687...
#   Embedding batch 55/687...
#   Embedding batch 56/687...
#   Embedding batch 57/687...
#   Embedding batch 58/687...
#   Embedding batch 59/687...
#   Embedding batch 60/687...
#   Embedding batch 61/687...
#   Embedding batch 62/687...
#   Embedding batch 63/687...
#   Embedding batch 64/687...
#   Embedding batch 65/687...
#   Embedding batch 66/687...
#   Embedding batch 67/687...
#   Embedding batch 68/687...
#   Embedding batch 69/687...
#   Embedding batch 70/687...
#   Embedding batch 71/687...
#   Embedding batch 72/687...
#   Embedding batch 73/687...
#   Embedding batch 74/687...
#   Embedding batch 75/687...
#   Embedding batch 76/687...
#   Embedding batch 77/687...
#   Embedding batch 78/687...
#   Embedding batch 79/687...
#   Embedding batch 80/687...
#   Embedding batch 81/687...
#   Embedding batch 82/687...
#   Embedding batch 83/687...
#   Embedding batch 84/687...
#   Embedding batch 85/687...
#   Embedding batch 86/687...
#   Embedding batch 87/687...
#   Embedding batch 88/687...
#   Embedding batch 89/687...
#   Embedding batch 90/687...
#   Embedding batch 91/687...
#   Embedding batch 92/687...
#   Embedding batch 93/687...
#   Embedding batch 94/687...
#   Embedding batch 95/687...
#   Embedding batch 96/687...
#   Embedding batch 97/687...
#   Embedding batch 98/687...
#   Embedding batch 99/687...
#   Embedding batch 100/687...
#   Embedding batch 101/687...
#   Embedding batch 102/687...
#   Embedding batch 103/687...
#   Embedding batch 104/687...
#   Embedding batch 105/687...
#   Embedding batch 106/687...
#   Embedding batch 107/687...
#   Embedding batch 108/687...
#   Embedding batch 109/687...
#   Embedding batch 110/687...
#   Embedding batch 111/687...
#   Embedding batch 112/687...
#   Embedding batch 113/687...
#   Embedding batch 114/687...
#   Embedding batch 115/687...
#   Embedding batch 116/687...
#   Embedding batch 117/687...
#   Embedding batch 118/687...
#   Embedding batch 119/687...
#   Embedding batch 120/687...
#   Embedding batch 121/687...
#   Embedding batch 122/687...
#   Embedding batch 123/687...
#   Embedding batch 124/687...
#   Embedding batch 125/687...
#   Embedding batch 126/687...
#   Embedding batch 127/687...
#   Embedding batch 128/687...
#   Embedding batch 129/687...
#   Embedding batch 130/687...
#   Embedding batch 131/687...
#   Embedding batch 132/687...
#   Embedding batch 133/687...
#   Embedding batch 134/687...
#   Embedding batch 135/687...
#   Embedding batch 136/687...
#   Embedding batch 137/687...
#   Embedding batch 138/687...
#   Embedding batch 139/687...
#   Embedding batch 140/687...
#   Embedding batch 141/687...
#   Embedding batch 142/687...
#   Embedding batch 143/687...
#   Embedding batch 144/687...
#   Embedding batch 145/687...
#   Embedding batch 146/687...
#   Embedding batch 147/687...
#   Embedding batch 148/687...
#   Embedding batch 149/687...
#   Embedding batch 150/687...
#   Embedding batch 151/687...
#   Embedding batch 152/687...
#   Embedding batch 153/687...
#   Embedding batch 154/687...
#   Embedding batch 155/687...
#   Embedding batch 156/687...
#   Embedding batch 157/687...
#   Embedding batch 158/687...
#   Embedding batch 159/687...
#   Embedding batch 160/687...
#   Embedding batch 161/687...
#   Embedding batch 162/687...
#   Embedding batch 163/687...
#   Embedding batch 164/687...
#   Embedding batch 165/687...
#   Embedding batch 166/687...
#   Embedding batch 167/687...
#   Embedding batch 168/687...
#   Embedding batch 169/687...
#   Embedding batch 170/687...
#   Embedding batch 171/687...
#   Embedding batch 172/687...
#   Embedding batch 173/687...
#   Embedding batch 174/687...
#   Embedding batch 175/687...
#   Embedding batch 176/687...
#   Embedding batch 177/687...
#   Embedding batch 178/687...
#   Embedding batch 179/687...
#   Embedding batch 180/687...
#   Embedding batch 181/687...
#   Embedding batch 182/687...
#   Embedding batch 183/687...
#   Embedding batch 184/687...
#   Embedding batch 185/687...
#   Embedding batch 186/687...
#   Embedding batch 187/687...
#   Embedding batch 188/687...
#   Embedding batch 189/687...
#   Embedding batch 190/687...
#   Embedding batch 191/687...
#   Embedding batch 192/687...
#   Embedding batch 193/687...
#   Embedding batch 194/687...
#   Embedding batch 195/687...
#   Embedding batch 196/687...
#   Embedding batch 197/687...
#   Embedding batch 198/687...
#   Embedding batch 199/687...
#   Embedding batch 200/687...
#   Embedding batch 201/687...
#   Embedding batch 202/687...
#   Embedding batch 203/687...
#   Embedding batch 204/687...
#   Embedding batch 205/687...
#   Embedding batch 206/687...
#   Embedding batch 207/687...
#   Embedding batch 208/687...
#   Embedding batch 209/687...
#   Embedding batch 210/687...
#   Embedding batch 211/687...
#   Embedding batch 212/687...
#   Embedding batch 213/687...
#   Embedding batch 214/687...
#   Embedding batch 215/687...
#   Embedding batch 216/687...
#   Embedding batch 217/687...
#   Embedding batch 218/687...
#   Embedding batch 219/687...
#   Embedding batch 220/687...
#   Embedding batch 221/687...
#   Embedding batch 222/687...
#   Embedding batch 223/687...
#   Embedding batch 224/687...
#   Embedding batch 225/687...
#   Embedding batch 226/687...
#   Embedding batch 227/687...
#   Embedding batch 228/687...
#   Embedding batch 229/687...
#   Embedding batch 230/687...
#   Embedding batch 231/687...
#   Embedding batch 232/687...
#   Embedding batch 233/687...
#   Embedding batch 234/687...
#   Embedding batch 235/687...
#   Embedding batch 236/687...
#   Embedding batch 237/687...
#   Embedding batch 238/687...
#   Embedding batch 239/687...
#   Embedding batch 240/687...
#   Embedding batch 241/687...
#   Embedding batch 242/687...
#   Embedding batch 243/687...
#   Embedding batch 244/687...
#   Embedding batch 245/687...
#   Embedding batch 246/687...
#   Embedding batch 247/687...
#   Embedding batch 248/687...
#   Embedding batch 249/687...
#   Embedding batch 250/687...
#   Embedding batch 251/687...
#   Embedding batch 252/687...
#   Embedding batch 253/687...
#   Embedding batch 254/687...
#   Embedding batch 255/687...
#   Embedding batch 256/687...
#   Embedding batch 257/687...
#   Embedding batch 258/687...
#   Embedding batch 259/687...
#   Embedding batch 260/687...
#   Embedding batch 261/687...
#   Embedding batch 262/687...
#   Embedding batch 263/687...
#   Embedding batch 264/687...
#   Embedding batch 265/687...
#   Embedding batch 266/687...
#   Embedding batch 267/687...
#   Embedding batch 268/687...
#   Embedding batch 269/687...
#   Embedding batch 270/687...
#   Embedding batch 271/687...
#   Embedding batch 272/687...
#   Embedding batch 273/687...
#   Embedding batch 274/687...
#   Embedding batch 275/687...
#   Embedding batch 276/687...
#   Embedding batch 277/687...
#   Embedding batch 278/687...
#   Embedding batch 279/687...
#   Embedding batch 280/687...
#   Embedding batch 281/687...
#   Embedding batch 282/687...
#   Embedding batch 283/687...
#   Embedding batch 284/687...
#   Embedding batch 285/687...
#   Embedding batch 286/687...
#   Embedding batch 287/687...
#   Embedding batch 288/687...
#   Embedding batch 289/687...
#   Embedding batch 290/687...
#   Embedding batch 291/687...
#   Embedding batch 292/687...
#   Embedding batch 293/687...
#   Embedding batch 294/687...
#   Embedding batch 295/687...
#   Embedding batch 296/687...
#   Embedding batch 297/687...
#   Embedding batch 298/687...
#   Embedding batch 299/687...
#   Embedding batch 300/687...
#   Embedding batch 301/687...
#   Embedding batch 302/687...
#   Embedding batch 303/687...
#   Embedding batch 304/687...
#   Embedding batch 305/687...
#   Embedding batch 306/687...
#   Embedding batch 307/687...
#   Embedding batch 308/687...
#   Embedding batch 309/687...
#   Embedding batch 310/687...
#   Embedding batch 311/687...
#   Embedding batch 312/687...
#   Embedding batch 313/687...
#   Embedding batch 314/687...
#   Embedding batch 315/687...
#   Embedding batch 316/687...
#   Embedding batch 317/687...
#   Embedding batch 318/687...
#   Embedding batch 319/687...
#   Embedding batch 320/687...
#   Embedding batch 321/687...
#   Embedding batch 322/687...
#   Embedding batch 323/687...
#   Embedding batch 324/687...
#   Embedding batch 325/687...
#   Embedding batch 326/687...
#   Embedding batch 327/687...
#   Embedding batch 328/687...
#   Embedding batch 329/687...
#   Embedding batch 330/687...
#   Embedding batch 331/687...
#   Embedding batch 332/687...
#   Embedding batch 333/687...
#   Embedding batch 334/687...
#   Embedding batch 335/687...
#   Embedding batch 336/687...
#   Embedding batch 337/687...
#   Embedding batch 338/687...
#   Embedding batch 339/687...
#   Embedding batch 340/687...
#   Embedding batch 341/687...
#   Embedding batch 342/687...
#   Embedding batch 343/687...
#   Embedding batch 344/687...
#   Embedding batch 345/687...
#   Embedding batch 346/687...
#   Embedding batch 347/687...
#   Embedding batch 348/687...
#   Embedding batch 349/687...
#   Embedding batch 350/687...
#   Embedding batch 351/687...
#   Embedding batch 352/687...
#   Embedding batch 353/687...
#   Embedding batch 354/687...
#   Embedding batch 355/687...
#   Embedding batch 356/687...
#   Embedding batch 357/687...
#   Embedding batch 358/687...
#   Embedding batch 359/687...
#   Embedding batch 360/687...
#   Embedding batch 361/687...
#   Embedding batch 362/687...
#   Embedding batch 363/687...
#   Embedding batch 364/687...
#   Embedding batch 365/687...
#   Embedding batch 366/687...
#   Embedding batch 367/687...
#   Embedding batch 368/687...
#   Embedding batch 369/687...
#   Embedding batch 370/687...
#   Embedding batch 371/687...
#   Embedding batch 372/687...
#   Embedding batch 373/687...
#   Embedding batch 374/687...
#   Embedding batch 375/687...
#   Embedding batch 376/687...
#   Embedding batch 377/687...
#   Embedding batch 378/687...
#   Embedding batch 379/687...
#   Embedding batch 380/687...
#   Embedding batch 381/687...
#   Embedding batch 382/687...
#   Embedding batch 383/687...
#   Embedding batch 384/687...
#   Embedding batch 385/687...
#   Embedding batch 386/687...
#   Embedding batch 387/687...
#   Embedding batch 388/687...
#   Embedding batch 389/687...
#   Embedding batch 390/687...
#   Embedding batch 391/687...
#   Embedding batch 392/687...
#   Embedding batch 393/687...
#   Embedding batch 394/687...
#   Embedding batch 395/687...
#   Embedding batch 396/687...
#   Embedding batch 397/687...
#   Embedding batch 398/687...
#   Embedding batch 399/687...
#   Embedding batch 400/687...
#   Embedding batch 401/687...
#   Embedding batch 402/687...
#   Embedding batch 403/687...
#   Embedding batch 404/687...
#   Embedding batch 405/687...
#   Embedding batch 406/687...
#   Embedding batch 407/687...
#   Embedding batch 408/687...
#   Embedding batch 409/687...
#   Embedding batch 410/687...
#   Embedding batch 411/687...
#   Embedding batch 412/687...
#   Embedding batch 413/687...
#   Embedding batch 414/687...
#   Embedding batch 415/687...
#   Embedding batch 416/687...
#   Embedding batch 417/687...
#   Embedding batch 418/687...
#   Embedding batch 419/687...
#   Embedding batch 420/687...
#   Embedding batch 421/687...
#   Embedding batch 422/687...
#   Embedding batch 423/687...
#   Embedding batch 424/687...
#   Embedding batch 425/687...
#   Embedding batch 426/687...
#   Embedding batch 427/687...
#   Embedding batch 428/687...
#   Embedding batch 429/687...
#   Embedding batch 430/687...
#   Embedding batch 431/687...
#   Embedding batch 432/687...
#   Embedding batch 433/687...
#   Embedding batch 434/687...
#   Embedding batch 435/687...
#   Embedding batch 436/687...
#   Embedding batch 437/687...
#   Embedding batch 438/687...
#   Embedding batch 439/687...
#   Embedding batch 440/687...
#   Embedding batch 441/687...
#   Embedding batch 442/687...
#   Embedding batch 443/687...
#   Embedding batch 444/687...
#   Embedding batch 445/687...
#   Embedding batch 446/687...
#   Embedding batch 447/687...
#   Embedding batch 448/687...
#   Embedding batch 449/687...
#   Embedding batch 450/687...
#   Embedding batch 451/687...
#   Embedding batch 452/687...
#   Embedding batch 453/687...
#   Embedding batch 454/687...
#   Embedding batch 455/687...
#   Embedding batch 456/687...
#   Embedding batch 457/687...
#   Embedding batch 458/687...
#   Embedding batch 459/687...
#   Embedding batch 460/687...
#   Embedding batch 461/687...
#   Embedding batch 462/687...
#   Embedding batch 463/687...
#   Embedding batch 464/687...
#   Embedding batch 465/687...
#   Embedding batch 466/687...
#   Embedding batch 467/687...
#   Embedding batch 468/687...
#   Embedding batch 469/687...
#   Embedding batch 470/687...
#   Embedding batch 471/687...
#   Embedding batch 472/687...
#   Embedding batch 473/687...
#   Embedding batch 474/687...
#   Embedding batch 475/687...
#   Embedding batch 476/687...
#   Embedding batch 477/687...
#   Embedding batch 478/687...
#   Embedding batch 479/687...
#   Embedding batch 480/687...
#   Embedding batch 481/687...
#   Embedding batch 482/687...
#   Embedding batch 483/687...
#   Embedding batch 484/687...
#   Embedding batch 485/687...
#   Embedding batch 486/687...
#   Embedding batch 487/687...
#   Embedding batch 488/687...
#   Embedding batch 489/687...
#   Embedding batch 490/687...
#   Embedding batch 491/687...
#   Embedding batch 492/687...
#   Embedding batch 493/687...
#   Embedding batch 494/687...
#   Embedding batch 495/687...
#   Embedding batch 496/687...
#   Embedding batch 497/687...
#   Embedding batch 498/687...
#   Embedding batch 499/687...
#   Embedding batch 500/687...
#   Embedding batch 501/687...
#   Embedding batch 502/687...
#   Embedding batch 503/687...
#   Embedding batch 504/687...
#   Embedding batch 505/687...
#   Embedding batch 506/687...
#   Embedding batch 507/687...
#   Embedding batch 508/687...
#   Embedding batch 509/687...
#   Embedding batch 510/687...
#   Embedding batch 511/687...
#   Embedding batch 512/687...
#   Embedding batch 513/687...
#   Embedding batch 514/687...
#   Embedding batch 515/687...
#   Embedding batch 516/687...
#   Embedding batch 517/687...
#   Embedding batch 518/687...
#   Embedding batch 519/687...
#   Embedding batch 520/687...
#   Embedding batch 521/687...
#   Embedding batch 522/687...
#   Embedding batch 523/687...
#   Embedding batch 524/687...
#   Embedding batch 525/687...
#   Embedding batch 526/687...
#   Embedding batch 527/687...
#   Embedding batch 528/687...
#   Embedding batch 529/687...
#   Embedding batch 530/687...
#   Embedding batch 531/687...
#   Embedding batch 532/687...
#   Embedding batch 533/687...
#   Embedding batch 534/687...
#   Embedding batch 535/687...
#   Embedding batch 536/687...
#   Embedding batch 537/687...
#   Embedding batch 538/687...
#   Embedding batch 539/687...
#   Embedding batch 540/687...
#   Embedding batch 541/687...
#   Embedding batch 542/687...
#   Embedding batch 543/687...
#   Embedding batch 544/687...
#   Embedding batch 545/687...
#   Embedding batch 546/687...
#   Embedding batch 547/687...
#   Embedding batch 548/687...
#   Embedding batch 549/687...
#   Embedding batch 550/687...
#   Embedding batch 551/687...
#   Embedding batch 552/687...
#   Embedding batch 553/687...
#   Embedding batch 554/687...
#   Embedding batch 555/687...
#   Embedding batch 556/687...
#   Embedding batch 557/687...
#   Embedding batch 558/687...
#   Embedding batch 559/687...
#   Embedding batch 560/687...
#   Embedding batch 561/687...
#   Embedding batch 562/687...
#   Embedding batch 563/687...
#   Embedding batch 564/687...
#   Embedding batch 565/687...
#   Embedding batch 566/687...
#   Embedding batch 567/687...
#   Embedding batch 568/687...
#   Embedding batch 569/687...
#   Embedding batch 570/687...
#   Embedding batch 571/687...
#   Embedding batch 572/687...
#   Embedding batch 573/687...
#   Embedding batch 574/687...
#   Embedding batch 575/687...
#   Embedding batch 576/687...
#   Embedding batch 577/687...
#   Embedding batch 578/687...
#   Embedding batch 579/687...
#   Embedding batch 580/687...
#   Embedding batch 581/687...
#   Embedding batch 582/687...
#   Embedding batch 583/687...
#   Embedding batch 584/687...
#   Embedding batch 585/687...
#   Embedding batch 586/687...
#   Embedding batch 587/687...
#   Embedding batch 588/687...
#   Embedding batch 589/687...
#   Embedding batch 590/687...
#   Embedding batch 591/687...
#   Embedding batch 592/687...
#   Embedding batch 593/687...
#   Embedding batch 594/687...
#   Embedding batch 595/687...
#   Embedding batch 596/687...
#   Embedding batch 597/687...
#   Embedding batch 598/687...
#   Embedding batch 599/687...
#   Embedding batch 600/687...
#   Embedding batch 601/687...
#   Embedding batch 602/687...
#   Embedding batch 603/687...
#   Embedding batch 604/687...
#   Embedding batch 605/687...
#   Embedding batch 606/687...
#   Embedding batch 607/687...
#   Embedding batch 608/687...
#   Embedding batch 609/687...
#   Embedding batch 610/687...
#   Embedding batch 611/687...
#   Embedding batch 612/687...
#   Embedding batch 613/687...
#   Embedding batch 614/687...
#   Embedding batch 615/687...
#   Embedding batch 616/687...
#   Embedding batch 617/687...
#   Embedding batch 618/687...
#   Embedding batch 619/687...
#   Embedding batch 620/687...
#   Embedding batch 621/687...
#   Embedding batch 622/687...
#   Embedding batch 623/687...
#   Embedding batch 624/687...
#   Embedding batch 625/687...
#   Embedding batch 626/687...
#   Embedding batch 627/687...
#   Embedding batch 628/687...
#   Embedding batch 629/687...
#   Embedding batch 630/687...
#   Embedding batch 631/687...
#   Embedding batch 632/687...
#   Embedding batch 633/687...
#   Embedding batch 634/687...
#   Embedding batch 635/687...
#   Embedding batch 636/687...
#   Embedding batch 637/687...
#   Embedding batch 638/687...
#   Embedding batch 639/687...
#   Embedding batch 640/687...
#   Embedding batch 641/687...
#   Embedding batch 642/687...
#   Embedding batch 643/687...
#   Embedding batch 644/687...
#   Embedding batch 645/687...
#   Embedding batch 646/687...
#   Embedding batch 647/687...
#   Embedding batch 648/687...
#   Embedding batch 649/687...
#   Embedding batch 650/687...
#   Embedding batch 651/687...
#   Embedding batch 652/687...
#   Embedding batch 653/687...
#   Embedding batch 654/687...
#   Embedding batch 655/687...
#   Embedding batch 656/687...
#   Embedding batch 657/687...
#   Embedding batch 658/687...
#   Embedding batch 659/687...
#   Embedding batch 660/687...
#   Embedding batch 661/687...
#   Embedding batch 662/687...
#   Embedding batch 663/687...
#   Embedding batch 664/687...
#   Embedding batch 665/687...
#   Embedding batch 666/687...
#   Embedding batch 667/687...
#   Embedding batch 668/687...
#   Embedding batch 669/687...
#   Embedding batch 670/687...
#   Embedding batch 671/687...
#   Embedding batch 672/687...
#   Embedding batch 673/687...
#   Embedding batch 674/687...
#   Embedding batch 675/687...
#   Embedding batch 676/687...
#   Embedding batch 677/687...
#   Embedding batch 678/687...
#   Embedding batch 679/687...
#   Embedding batch 680/687...
#   Embedding batch 681/687...
#   Embedding batch 682/687...
#   Embedding batch 683/687...
#   Embedding batch 684/687...
#   Embedding batch 685/687...
#   Embedding batch 686/687...
#   Embedding batch 687/687...
# Embedded 68682 text(s) using Nemotron (OpenRouter)
# Saved embeddings: (68682, 2048) (model: nemotron-3-embed-1b)

# %%
# Embed query

def embed_query(text):
    if used_model == "nemotron-3-embed-1b":
        response = openrouter_client.embeddings.create(
            model="nvidia/nemotron-3-embed-1b:free",
            input=[text],
            encoding_format="float"
        )
        return np.array([response.data[0].embedding])

    result = client.models.embed_content(
        model="gemini-embedding-001",
        contents=[text]
    )
    return np.array([result.embeddings[0].values])

# %%
# Check cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

scores = cosine_similarity(query_embedding, doc_embeddings)[0]

# Build a dict of {article_id: score} — same shape topK expects
embedding_scores = {}
for i in range(len(doc_ids)):
    embedding_scores[doc_ids[i]] = scores[i]

# Sort descending by score
sorted_embedding = dict(sorted(embedding_scores.items(), key=lambda x: x[1], reverse=True))

# Reuse your existing topK function
topK(sorted_embedding, df, 10)
# Out:
# [('68817',
#   np.float64(0.5318485233753766),
#   'Bull Market? Bear Market? Something Else? What Should Investors DO?',
#   'Is this a new bear market, and if so, how can investors adapt? Is this still a bull market, and investors should just take a deep breath and buy? Or is it a completely DIFFERENT kind of market, one more akin to what we saw in the 80s and 90s rather than 2009-â\x80¦'),
#  ('69166',
#   np.float64(0.5283833051736526),
#   'Bull Market? Bear Market? Something Else? What Should Investors DO?',
#   'A new bear market?...How can investors adapt? Is this still a bull market, and should investors just take a deep breath and buy? Or a completely DIFFERENT kind of market?'),
#  ('43793',
#   np.float64(0.4548240732463333),
#   'Go East For A Bull Market',
#   'The big bright spot this year has been the Japanese market, where stocks look to have entered into what looks like a very powerful bull market.'),
#  ('209515',
#   np.float64(0.4481538579378688),
#   'If there is value, buyers will find you in the middle of ocean, in the dead of the night: Siddharth Oberoi, Prudent Equity',
#   '"Given that our domestic economy is growing at a decent rate, the investor community currently believes that every market decline is a buying opportunity and is, thus, investing heavily. However, as the saying goes, â\x80\x9cif there is value, buyers will find you inâ\x80¦'),
#  ('26389',
#   np.float64(0.42830546785274703),
#   'Insider Today: You should buy a house now',
#   'As bad as the housing market seems nowadays, now might actually be your best chance at getting a home.'),
#  ('124058',
#   np.float64(0.39082628962541366),
#   'Why do investors believe that small-cap, and mid-cap are good bets for the future?',
#   'With good trust, surplus funding, and strong financials, small and midcap companies are worth betting on in the stock market'),
#  ('27257',
#   np.float64(0.38777328690867097),
#   '3 tips experts gave me to pull money out of the stock market without getting slammed by taxes',
#   'During the pandemic, I recklessly bought stocks. I want to sell most of them before the year ends, so I asked the experts what I should do.'),
#  ('77282',
#   np.float64(0.38698163254581),
#   'Experts Share Ways Investors Can Adapt As Middle East Conflict Rages',
#   'The Middle East conflict remains front and center for investors, with headlines and news flow driving noteworthy action in stocks, energy markets, precious metals.'),
#  ('61589',
#   np.float64(0.3863872449364491),
#   'Big Tech earnings can make or break this market',
#   "In an unstable economic climate marked by geopolitical unrest, concerns about the Federal Reserve and soaring Treasury yields, investors are closely watching this week's Big Tech earnings for clues about where the volatile stock market may head next."),
#  ('29075',
#   np.float64(0.3839323202886032),
#   "The Dow's transportation index is ringing alarm bells about the broader stock market",
#   'The trend is worrying because transportation stocks are viewed as a leading indicator for both the stock market and economy.')]

# %% [markdown]
# MODEL INTEGRATION

# %%
prompt = f"""
You are a professional assistant. Examine the sorted,
embedded documents and articles. Answer the user query in a detailed way,
including citations and references to the documents. For references, use the
title of the documents.

Content: {topK(sorted_embedding, df, 20)}

Question: {user_response}

Answer:
"""

# In the new SDK, use client.models.generate_content
response = client.models.generate_content(
    model="gemini-3.5-flash-lite",
    contents=prompt
)

print(response.text)
# Out:
# Based on the provided documents, the current stock market presents a complex and mixed picture characterized by volatility, mixed buy and sell signals, and varying regional trends.
#
# ### What the Current Stock Market is Like
# * **Mixed Signals and Volatility:** The stock market is currently grasping for direction, flashing multiple conflicting buy and sell signals at the same time (**"The stock market is grasping for direction as multiple buy and sell signals flash at the same time"**). It is operating in an unstable economic climate influenced by geopolitical unrest (such as the Middle East conflict), concerns regarding the Federal Reserve, and soaring Treasury yields (**"Big Tech earnings can make or break this market"**).
# * **Uncertain Market Phases:** Investors are actively questioning the overall trend—wondering if they are looking at a new bear market, a continuation of a bull market, or an entirely different economic environment akin to the 1980s and 1990s (**"Bull Market? Bear Market? Something Else? What Should Investors DO?"**).
# * **Bright Spots and Regional Disparities:** While domestic economies and certain regions show resilience—such as the Japanese market, which has entered a powerful bull market (**"Go East For A Bull Market"**)—other indicators, like the Dow's transportation index, are ringing alarm bells as a leading indicator of economic caution (**"The Dow's transportation index is ringing alarm bells about the broader stock market"**). Furthermore, some experts like Bill Gross suggest passing on standard stocks and bonds due to them being "clearly overvalued" after massive sell-offs (**"Bill Gross says he would avoid bonds and 'clearly overvalued' stocks even after massive sell-off"**).
#
# ---
#
# ### What Should You Invest In?
# Depending on which strategy or sector experts point toward in the documents, several areas are being highlighted for potential investment:
#
# 1. **Small-Cap and Mid-Cap Companies:** Due to good trust, surplus funding, and strong financials, small- and mid-cap companies are viewed by some as solid, worthwhile bets for the future (**"Why do investors believe that small-cap, and mid-cap are good bets for the future?"**).
# 2. **Specific Market Sectors:** Market commentators like Sanjiv Bhasin suggest that consolidation is healthy and point toward sectors such as **metals, banks, construction, and autos** to drive future market momentum (**"We are headed to 19,700-20,000 by Diwali; 4 sectors to drive market higher: Sanjiv Bhasin"**).
# 3. **Global/International Opportunities:** Investors looking outside traditional or local boundaries have found bright spots internationally, particularly in the **Japanese market** (**"Go East For A Bull Market"**).
# 4. **Dividend-Growth Stocks:** For contrarian investors willing to buy while fear is still prevalent in the market, 2024 is framed as a great year to target top dividend-growers (**"3 Top Dividend Growers For 2024"**).
# 5. **Alternative Assets / Cryptocurrencies:** In specific niches like crypto, some observers recommend looking at new launches or projects (such as Bitcoin Spark) during market bottoms to seize potential wealth creation waves (**"Seizing the Wealth Wave: Bitcoin Spark’s Launch in Bear Market Bottom"**).
#
# *Disclaimer: Since market conditions are volatile and sending mixed signals, it is always recommended to evaluate your personal risk tolerance and consult with a financial professional before making investment decisions.*

# %% [markdown]
# # GRADIO IMPLEMENTATION

# %%
import gradio as gr

def search_and_answer(query):
    try:
        # 1. Embed query
        q_embedding = embed_query(query)

        # 2. Cosine similarity
        scores = cosine_similarity(q_embedding, doc_embeddings).ravel()

        # 3. Top-K
        embedding_scores = {}
        for i in range(len(doc_ids)):
            embedding_scores[doc_ids[i]] = float(scores[i])
        sorted_scores = dict(sorted(embedding_scores.items(), key=lambda x: x[1], reverse=True))

        results = topK(sorted_scores, df, 5)

        # 4. Format results + build context
        context = ""
        result_text = ""
        for rank, (aid, score, title, desc) in enumerate(results, 1):
            result_text += f"**Rank {rank}** (score: {score:.4f})\n"
            result_text += f"**{title}**\n{desc}\n\n"
            context += f"[{rank}] {title}\n{desc}\n\n"

        # 5. Ask Gemini
        prompt = f"""
You are a professional assistant. Answer the user query using the provided documents.
Include citations using document titles.

Content: {context}

Question: {query}

Answer:
"""

        response = client.models.generate_content(
            model="gemini-3.5-flash-lite",
            contents=prompt
        )

        return result_text, response.text

    except Exception as e:
        import traceback
        error_msg = traceback.format_exc()
        return f"Error: {error_msg}", str(e)

# Gradio 6.x compatible UI
with gr.Blocks(title="Mini RAG") as demo:
    gr.Markdown("# Mini RAG Search")
    query_input = gr.Textbox(label="Your question", placeholder="What's new?")
    search_btn = gr.Button("Search")
    results_output = gr.Markdown(label="Retrieved Documents")
    answer_output = gr.Textbox(label="RAG Answer", lines=20)

    search_btn.click(
        fn=search_and_answer,
        inputs=query_input,
        outputs=[results_output, answer_output]
    )

demo.launch(debug=True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://ea0ccea0756b11f772.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ea0ccea0756b11f772.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
